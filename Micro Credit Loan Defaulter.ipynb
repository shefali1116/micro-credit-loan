# %% [markdown]
# # Import modules

# %%
#Importing all the necessary libraries

#linear algebra
import numpy as np

#data processing
import pandas as pd

#data visualization
import seaborn as sns 
import matplotlib.pyplot as plt

#importing warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv("prjct.csv")
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
#Checking the Shape of data type
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# Observation:
#
#     The dataset consist of 209593 rows and 37 columns.

# %%
#Checking the numbers of columns.
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#dropping unecessary column
df1=df.drop(columns=['Unnamed: 0'],axis=1)
df1.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %% [markdown]
# # Checking the Missing Values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Summary Statistics

# %%
#Checking the summary of the dataset
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# ...

# %% [markdown]
# Observation:
#
#         1.There are no Null Values or Missing values in the dataset as seen in the count.
#         2.Maximum aon is 999860.755 and the minimum aon is -48.000 there is very huge difference.
#         3.The data are right skewed because mean is greater than median.
#         4.The difference between 75% and Maximum is higher in many columns. So Outliers are present in these columns which    needs to be removed.

# %% [markdown]
# # Data Exploration\Analysis

# %%
#Checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# Observation:
#
#         there are 209593 examples and 37 features, including target variable(label). 21 of the features are float, 13 are   integers and 3 are objects.

# %% [markdown]
# # To check the Correlation

# %%
df_cor=df.corr()
df_cor
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %% [markdown]
# Here we can see the correlation between the columns. For better understanding we can see it via visualization(with help of heatmap )

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_cor,annot=True,cmap='BuPu')
plt.show()

# %% [markdown]
# # Correlation with target column i.e. is label

# %%
#Correlation with target column
plt.figure(figsize=(12,6))
df.drop('label',axis=1).corrwith(df['label']).plot(kind='bar',grid=True)
plt.xticks(rotation='vertical')
plt.title("Correlation with target variable")
# Out:
# Text(0.5, 1.0, 'Correlation with target variable')

# %% [markdown]
# Observation:
#
#     cnt_ma_rech30 and cnt_ma_rech90 both columns are highly correlated with target variable column.
#     fr_ma_rech30 is very less correlated with label.
#     aon,medianmarechpreba30 and fr_da_rech90 are negatively correlated with label.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
#Checking the number of labels
sns.countplot(x='label',data=df,palette='rainbow')
plt.title('No of Labels',fontsize=18)
plt.show()

print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Observation:
#
#     Here 1 stands for success and 0 stands for failure.
#     Out of 209593 cases 183431 are success and 26162 are failure labels.
#     The dataset is imbalanced.

# %%
#Checking the age on cellular network in days of people
plt.figure(figsize=(8,6))
sns.countplot(x='aon',data=df,palette='rainbow')
plt.title('age on cellular network in days',fontsize=18)
plt.show()

print(df['aon'].value_counts())
# Out:
# 95.0000        392
# 92.0000        362
# 96.0000        357
# 99.0000        356
# 157.0000       349
#               ...
# 832037.7123      1
# 932056.6019      1
# 890451.7726      1
# 670233.0281      1
# 919992.9709      1
# Name: aon, Length: 4507, dtype: int64

# %%
#checking the mean of number of times main account recharged in last 30 days
rech30=df['cnt_ma_rech30'].hist(bins=max(df['cnt_ma_rech30']-min(df['cnt_ma_rech30'])))
mean_val=np.mean(df['cnt_ma_rech30'])
plt.axvline(mean_val,linewidth=4, color='red', label='mean cnt_ma_rech30')
plt.xlabel('cnt_ma_rech30')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
#Histogram of Total amount of loans taken by user in last 30 days
sns.distplot(df['amnt_loans30'],color='r')
plt.title("Histogram of Total amount of loans taken by user in last 30 days")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Our feature variable of interest is label
#
# It already contains only two numbers 0 and 1.
#
# 1 stands for Success
#
# 0 stands for Failure

# %%
#Exploring aon vs label via FaceGrid
facet=sns.FacetGrid(df,col='label')
facet.map(sns.distplot,"aon")
plt.show()

# %%
#payback30 vs label using countplot
plt.figure(figsize=(20,6))
sns.countplot(x="payback30",hue='label',data=df,palette='rainbow')
plt.title("Average payback time in days over last 30 days according to label")
plt.ylabel('label')
plt.xticks(rotation='vertical')
plt.show()

print(df.groupby('payback30')['label'].value_counts())
# Out:
# payback30   label
# 0.000000    1        84296
#             0        22416
# 1.000000    1         2260
#             0           19
# 1.041667    1            1
#                      ...
# 169.000000  1            2
# 169.500000  1            1
# 170.000000  1            1
# 170.500000  1            1
# 171.500000  1            1
# Name: label, Length: 1835, dtype: int64

# %%
#Amount of last recharge vs label using countplot
plt.figure(figsize=(20,6))
sns.countplot(x="last_rech_amt_ma",hue='label',data=df,palette='rainbow')
plt.title("Amount of last recharge of main account (in Indonesian Rupiah) according to label")
plt.ylabel('label')
plt.xticks(rotation='vertical')
plt.show()

print(df.groupby('last_rech_amt_ma')['label'].value_counts())
# Out:
# last_rech_amt_ma  label
# 0                 1        11805
#                   0         9190
# 173               1          636
#                   0          175
# 177               1            5
#                            ...
# 32000             1           22
#                   0           10
# 34783             1            1
# 55000             1           20
#                   0            8
# Name: label, Length: 121, dtype: int64

# %% [markdown]
# # Converting the categorical data into numeric variables

# %%
#Transform non numeric columns into numeric columns
from sklearn.preprocessing import LabelEncoder
 
le=LabelEncoder()
for column in df.columns:
        if df[column].dtype==np.number:
            continue
            df[column]=le.fit_transform(df[column])

# %%
for column in df.columns:
    if df[column].dtypes=='object':
        le=LabelEncoder()
        df[column]=le.fit_transform(df[column])

# %% [markdown]
# # Model Training

# %%
#dropping unecessary column
df1=df.drop(columns=['Unnamed: 0'],axis=1)
df1.head()
# Out:
#    label  msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  104157  241.0     21.228000     21.228000    159.42    159.42
# 4      1    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df1.head()
# Out:
#    label  msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  104157  241.0     21.228000     21.228000    159.42    159.42
# 4      1    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
#Splitting the data into input and output variable.
x=df1.drop(columns=['label'],axis=1)
x.head()
# Out:
#    msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3  104157  241.0     21.228000     21.228000    159.42    159.42
# 4    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               41.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
y=df1['label']
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
#Checking the shape of input and target variable 
print(x.shape,'\t\t',y.shape)
# Out:
# (209593, 35) 		 (209593,)

# %%
#Scaling in input variable
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=22,random_state=43,stratify=y)

# %%
#Checking the shape

print(x_train.shape,'\t\t',x_test.shape)
# Out:
# (209571, 35) 		 (22, 35)

# %%
#Checking the shape

print(y_train.shape,'\t\t',y_test.shape)
# Out:
# (209571,) 		 (22,)

# %%
#Importing all the model library

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

#Importing Boosting models
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier

#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
rfc=RandomForestClassifier(n_estimators=100)
rfc.fit(x_train,y_train)
ypred=rfc.predict(x_test)
rfc.score(x_train,y_train)
accrfc=round(rfc.score(x_train,y_train)*100,2)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
acc=round(lr.score(x_train,y_train)*100,2)

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
ypred=knn.predict(x_test)
acc=round(knn.score(x_train,y_train)*100,2)

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
ypred=gnb.predict(x_test)
acc=round(gnb.score(x_train,y_train)*100,2)

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print('Accuracy score of',svc,'is:')
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print('Accuracy score of',dtc,'is:')
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
